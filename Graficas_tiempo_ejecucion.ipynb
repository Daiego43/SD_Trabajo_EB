# %% [markdown]
# # Gráficas de tiempo en función del numero de hilos o procesos implicados en el cómputo del algoritmo
#
# ## Características del equipo/s utilizado/s para la medición
# Para las mediciones de estos tiempos se ha utilizado un sólo ordenador. Características
#
# - Modelo: msi-gf63 thin
# - CPU: intelcore i7 9th generation
# - Nº cores: 12

# %%
import plot_data as p

# %%
tp = p.timePlotting()

# %% [markdown]
# ## Tiempos del archivo datos_1X.txt

# %%
tp.plotData(tp.tiempo_1X_hilos, 'hilos')

# %%
tp.plotData(tp.tiempo_1X_procesos, 'procesos')

# %% [markdown]
# ## Tiempos del archivo datos_10X.txt

# %%
tp.plotData(tp.tiempo_10X_hilos, 'hilos')

# %%
tp.plotData(tp.tiempo_10X_procesos, 'procesos')

# %% [markdown]
# ## Tiempos del archivo datos_1000X.txt

# %%
tp.plotData(tp.tiempo_1000X_hilos, 'hilos')

# %%
tp.plotData(tp.tiempo_1000X_procesos, 'procesos')
